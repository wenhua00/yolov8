# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.yaml')  # build a new model from YAMLmodel = YOLO('/home/tin/project/oepncv/ultralytics/ultralytics/yolov8n-seg.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n-seg.pt')  # load a pretrained model (recommended for training)
# # Train the model
results = model.train(data='/home/haoyang-22/project/event-camera/ultralytics/ultralytics/cfg/datasets/detect0209.yaml', epochs=50, imgsz=720)
# Out:
# Ultralytics YOLOv8.1.20 🚀 Python-3.8.18 torch-2.2.1+cu121 CUDA:0 (NVIDIA RTX A4500, 20145MiB)
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('/home/haoyang-22/project/event-camera/ultralytics/detect_0301/runs/segment/train5/weights/best.pt')

# Open the video file
video_path = "/home/haoyang-22/project/event-camera/0225_detectweight/f_100g_recording_2024-02-25_14-35-36 00_06_20-00_06_44.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model.predict(frame,line_width=1)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)
        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 416x736 7 0s, 5.7ms
# Speed: 1.7ms preprocess, 5.7ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 0s, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 0s, 5.4ms
# Speed: 2.1ms preprocess, 5.4ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 0s, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 7 0s, 5.9ms
# Speed: 2.5ms preprocess, 5.9ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 8 0s, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 0s, 5.3ms
# Speed: 2.1ms preprocess, 5.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 736)
#
# 0: 416x736 9 0s, 4.7ms
# Speed: 2.1ms preprocess, 4.7ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 736)
#
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('/home/haoyang-22/project/event-camera/ultralytics/detect_0301/runs/segment/train5/weights/best.pt')

# Open the video file
video_path = "/home/haoyang-22/project/event-camera/0225_detectweight/f_100g_recording_2024-02-25_14-35-36 00_06_20-00_06_44.mp4"
model.predict(video_path,line_width=2)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/711) /home/haoyang-22/project/event-camera/0225_detectweight/f_100g_recording_2024-02-25_14-35-36 00_06_20-00_06_44.mp4: 416x736 7 0s, 7.3ms
# video 1/1 (2/711) /home/haoyang-22/project/event-camera/0225_detectweight/f_100g_recording_2024-02-25_14-35-36 00_06_20-00_06_44.mp4: 416x736 9 0s, 6.5ms
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
#Qmodel = YOLO('/home/haoyang-22/project/event-camera/ultralytics/detect_0301/yolov8n.pt')
model = YOLO('/home/haoyang-22/project/event-camera/ultralytics/detect_0301/yolov8n-seg.pt')
#model = YOLO('/home/haoyang-22/project/event-camera/ultralytics/detect_0301/yolov8n-pose.pt')


# Open the video file
video_path = "/home/haoyang-22/project/event-camera/ultralytics/detect_0301/100 Different Ways to Walk by Kevin Parry (Animation Reference with Music).mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x640 (no detections), 4.0ms
# Speed: 2.1ms preprocess, 4.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 4.8ms
# Speed: 2.3ms preprocess, 4.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 4.6ms
# Speed: 2.0ms preprocess, 4.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 4.1ms
# Speed: 2.0ms preprocess, 4.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 4.5ms
# Speed: 2.0ms preprocess, 4.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 4.0ms
# Speed: 1.9ms preprocess, 4.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 4.0ms
# ...
