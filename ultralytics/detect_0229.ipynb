# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.yaml')  # build a new model from YAMLmodel = YOLO('/home/tin/project/oepncv/ultralytics/ultralytics/yolov8n-seg.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n-seg.pt')  # load a pretrained model (recommended for training)
# # Train the model
results = model.train(data='detect0209.yaml', epochs=50, imgsz=640)
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.8.18 torch-2.2.1+cu121 CPU (11th Gen Intel Core(TM) i7-11800H 2.30GHz)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.pt')  # load an official model
model = YOLO('/home/tin/project/oepncv/ultralytics/runs/segment/train9/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps   # a list contains map50-95(B) of each category
metrics.seg.map    # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps   # a list contains map50-95(M) of each category
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.8.18 torch-2.2.1+cu121 CPU (11th Gen Intel Core(TM) i7-11800H 2.30GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3258259 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /home/tin/project/oepncv/ultralytics/ultralytics/detect_0229/val/labels.cache... 22 images, 0 backgrounds, 0 corrupt: 100%|██████████| 22/22 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:04<00:00,  2.03s/it]
#                    all         22        174      0.886      0.896      0.925      0.535      0.672      0.742      0.718      0.278
# Speed: 1.0ms preprocess, 149.1ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /home/tin/project/oepncv/ultralytics/runs/segment/val
# array([    0.27846])

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.pt')  # load an official model
model = YOLO('/home/tin/project/oepncv/ultralytics/runs/segment/train9/weights/best.pt')  # load a custom model

# Predict with the model
results = model('/home/tin/project/oepncv/event_det/test/frame_000900.png')  # predict on an image
# Out:
# image 1/1 /home/tin/project/oepncv/event_det/test/frame_000900.png: 384x640 7 white_ps, 287.9ms
# Speed: 1.0ms preprocess, 287.9ms inference, 17.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n-seg.pt')
model = YOLO('/home/tin/project/oepncv/ultralytics/runs/segment/train9/weights/best.pt')  # load a custom model


# Open the video file
video_path = "/home/tin/project/oepncv/event_det/h7.5_v10_recording_2024-02-19_15-45-57 00_05_23.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 415.3ms
# Speed: 1.2ms preprocess, 415.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 396.8ms
# Speed: 2.6ms preprocess, 396.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 381.7ms
# Speed: 9.8ms preprocess, 381.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 318.8ms
# Speed: 1.8ms preprocess, 318.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.7ms
# Speed: 1.3ms preprocess, 89.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.7ms
# Speed: 1.2ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.pt')  # load an official model
model = YOLO('/home/tin/project/oepncv/ultralytics/runs/segment/train9/weights/best.pt')  # load a custom trained model

# Export the model
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.8.18 torch-2.2.1+cu121 CPU (11th Gen Intel Core(TM) i7-11800H 2.30GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3258259 parameters, 0 gradients, 12.0 GFLOPs
#
# PyTorch: starting from '/home/tin/project/oepncv/ultralytics/runs/segment/train9/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 37, 8400), (1, 32, 160, 160)) (6.4 MB)
#
# ONNX: starting export with onnx 1.13.1 opset 17...
# ONNX: export success ✅ 1.2s, saved as '/home/tin/project/oepncv/ultralytics/runs/segment/train9/weights/best.onnx' (12.6 MB)
#
# Export complete (3.8s)
# Results saved to /home/tin/project/oepncv/ultralytics/runs/segment/train9/weights
# Predict:         yolo predict task=segment model=/home/tin/project/oepncv/ultralytics/runs/segment/train9/weights/best.onnx imgsz=640
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.yaml')  # build a new model from YAMLmodel = YOLO('/home/tin/project/oepncv/ultralytics/ultralytics/yolov8n-seg.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n-seg.pt')  # load a pretrained model (recommended for training)
# # Train the model
results = model.train(data='detect0209.yaml', epochs=50, imgsz=720)
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.8.18 torch-2.2.1+cu121 CPU (11th Gen Intel Core(TM) i7-11800H 2.30GHz)
# ...
